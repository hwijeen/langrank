# %%
import lightgbm as lgb
import matplotlib.pyplot as plt

# %%
bst_wopreproc = lgb.Booster(model_file='tmp/model_wopreproc.txt')
bst = lgb.Booster(model_file='tmp/model.txt')
# Out:
# ---------------------------------------------------------------------------
# LightGBMError                             Traceback (most recent call last)
# <ipython-input-5-a224b56dbd49> in <module>
# ----> 1 bst_wopreproc = lgb.Booster(model_file='tmp/model_wopreproc.txt.txt')
#       2 bst = lgb.Booster(model_file='tmp/model.txt')
#
# ~/opt/anaconda3/envs/lang2vec/lib/python3.7/site-packages/lightgbm/basic.py in __init__(self, params, train_set, model_file, model_str, silent)
#    1742                 c_str(model_file),
#    1743                 ctypes.byref(out_num_iterations),
# -> 1744                 ctypes.byref(self.handle)))
#    1745             out_num_class = ctypes.c_int(0)
#    1746             _safe_call(_LIB.LGBM_BoosterGetNumClasses(
#
# ~/opt/anaconda3/envs/lang2vec/lib/python3.7/site-packages/lightgbm/basic.py in _safe_call(ret)
#      43     """
#      44     if ret != 0:
# ---> 45         raise LightGBMError(decode_string(_LIB.LGBM_GetLastError()))
#      46
# ...

# %%
plot = lgb.plot_importance(bst)
